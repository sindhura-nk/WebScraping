# %% [markdown]
# Webscraping
#
# ![image.png](attachment:image.png)

# %%
# %pip install beautifulsoup4 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Restart and run all cells
# ## Fetch the html code from website

# %%
import requests

# %%
url = "https://www.thehindu.com/latest-news/"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.content
print(str(data)[0:1000])
# Out:
# b'<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en"><head><title>\n\tLatest News - The Hindu\n</title><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="title" content="Latest News" /><meta name="description" content="Read the Latest News On Business, Politics, Sports, Entertainment &amp;amp; Much More From India And Around The World At The Hindu" /><meta name="robots" content="index, follow" /><meta name="robots" content="max-image-preview:large"><meta name="atdlayout" content="sectionpage" /><meta name="twitter:title" content="Latest News"><meta name="twitter:description" content="Read the Latest News On Business, Politics, Sports, Entertainment &amp;amp; Much More From India And Around The World At The Hindu"><meta name="twitter:image" content="https://www.thehindu.com/theme/images/th-online/OG-sections.png"><meta property="og:title" content="Lates
# ...

# %%
from bs4 import BeautifulSoup
bs = BeautifulSoup(data)

# %%
## Finding news articles
news = bs.find_all('div',class_='right-content')
news
# Out:
# [<div class="right-content"><div class="label"><a href="https://www.thehindu.com/news/cities/chennai/">Chennai
#  </a></div><div class="news-time time" data-published="2024-04-14T21:22:28+05:30"></div><h3 class="title"><a href="https://www.thehindu.com/news/cities/chennai/being-homeless-and-getting-inked/article68053722.ece">
#  Being ‘homeless’ and getting inked
#  </a></h3><div class="by-line"><div class="author-name"><a class="person-name lnk" href="https://www.thehindu.com/profile/author/Liffy-Thomas-590/">Liffy Thomas</a></div></div></div>,
#  <div class="right-content"><div class="label"><a href="https://www.thehindu.com/news/national/karnataka/">Karnataka
#  </a></div><div class="news-time time" data-published="2024-04-14T21:19:39+05:30"></div><h3 class="title"><a href="https://www.thehindu.com/news/national/karnataka/fearing-defeat-bjp-denied-ticket-to-simha/article68064521.ece">
#  Fearing defeat, BJP denied ticket to Simha
# ...

# %%
news[0]
# Out:
# <div class="right-content"><div class="label"><a href="https://www.thehindu.com/news/cities/chennai/">Chennai
# </a></div><div class="news-time time" data-published="2024-04-14T21:22:28+05:30"></div><h3 class="title"><a href="https://www.thehindu.com/news/cities/chennai/being-homeless-and-getting-inked/article68053722.ece">
# Being ‘homeless’ and getting inked
# </a></h3><div class="by-line"><div class="author-name"><a class="person-name lnk" href="https://www.thehindu.com/profile/author/Liffy-Thomas-590/">Liffy Thomas</a></div></div></div>

# %%
news[0].text
# Out:
# 'Chennai\n\nBeing ‘homeless’ and getting inked\nLiffy Thomas'

# %%
news_titles = []
for i in news:
    news_titles.append(i.text)
news_titles
# Out:
# ['Chennai\n\nBeing ‘homeless’ and getting inked\nLiffy Thomas',
#  'Karnataka\n\nFearing defeat, BJP denied ticket to Simha\n The Hindu Bureau',
#  'Tamil Nadu\n\nGovernor, T.N. officials pay tributes to Ambedkar on his birth anniversary\n The Hindu Bureau',
#  'Karnataka\n\nHDD takes potshots at CM, Dy. CM\n\xa0\n The Hindu Bureau',
#  'Karnataka\n\nBSY calls on Prasad\n The Hindu Bureau',
#  'Karnataka\n\nWill step out of palace to be with people: Yaduveer\n The Hindu Bureau',
#  'Lok Sabha Elections\n\nCongress announces 10 more candidates for Lok Sabha polls\n PTI',
#  'Chennai\n\nTwo persons held for attempting to murder medical student near Madras Medical College\n The Hindu Bureau',
#  'Karnataka\n\nWomen’s Commission registers suo motu case against former MLA Sanjay Patil\n The Hindu Bureau',
#  'Lok Sabha Elections\n\nLok Sabha polls | Islamic federation from Coimbatore meets CM Stalin, extends solidarity\n The Hindu Bureau',
# ...

# %%
latest_date = bs.find_all('div',class_='latest-date')
latest_date[0].text
# Out:
# 'Sunday, 14th April 2024\n'

# %%
latest_date[0].text.split(',')
# Out:
# ['Sunday', ' 14th April 2024\n']

# %%
day = latest_date[0].text.split(',')[0]
date = latest_date[0].text.split(',')[1]

# %%
day
# Out:
# 'Sunday'

# %%
date
# Out:
# ' 14th April 2024\n'

# %%
date =date.split('\n')[0]
date
# Out:
# ' 14th April 2024'

# %%
news[0].a.get('href')
# Out:
# 'https://www.thehindu.com/news/cities/chennai/'

# %%
links = []
for i in news:
    links.append(i.a.get('href'))
links
# Out:
# ['https://www.thehindu.com/news/cities/chennai/',
#  'https://www.thehindu.com/news/national/karnataka/',
#  'https://www.thehindu.com/news/national/tamil-nadu/',
#  'https://www.thehindu.com/news/national/karnataka/',
#  'https://www.thehindu.com/news/national/karnataka/',
#  'https://www.thehindu.com/news/national/karnataka/',
#  'https://www.thehindu.com/elections/lok-sabha/',
#  'https://www.thehindu.com/news/cities/chennai/',
#  'https://www.thehindu.com/news/national/karnataka/',
#  'https://www.thehindu.com/elections/lok-sabha/',
#  'https://www.thehindu.com/news/cities/bangalore/',
#  'https://www.thehindu.com/elections/lok-sabha/',
#  None,
#  'https://www.thehindu.com/elections/lok-sabha/',
#  'https://www.thehindu.com/elections/lok-sabha/',
#  'https://www.thehindu.com/news/national/karnataka/',
#  'https://www.thehindu.com/news/national/telangana/',
#  'https://www.thehindu.com/sport/',
#  'https://www.thehindu.com/news/national/manipur/',
# ...

# %% [markdown]
# ## Create a dataframe containing all values

# %%
dct = {'News Titles':news_titles,
      'Day':day,
      'Date':date,
       'Links':links
      }

# %%
import pandas as pd

# %%
df_news = pd.DataFrame(dct)
df_news
# Out:
#                                            News Titles     Day  \
# 0    Chennai\n\nBeing ‘homeless’ and getting inked\...  Sunday
# 1    Karnataka\n\nFearing defeat, BJP denied ticket...  Sunday
# 2    Tamil Nadu\n\nGovernor, T.N. officials pay tri...  Sunday
# 3    Karnataka\n\nHDD takes potshots at CM, Dy. CM\...  Sunday
# 4    Karnataka\n\nBSY calls on Prasad\n The Hindu B...  Sunday
# ..                                                 ...     ...
# 195  Kochi\n\nOptimism over resolution of mass litu...  Sunday
# 196  \npremium\nMessage in a meteor\nJayam Ananthar...  Sunday
# 197  \npremium\nKalvakuntla Kavitha | Under the sha...  Sunday
# 198  Football\n\nBruno Fernandes earns unconvincing...  Sunday
# 199  Football\n\nHaaland scores as Man City routs L...  Sunday
#
#                  Date                                              Links
# 0     14th April 2024      https://www.thehindu.com/news/cities/chennai/
# ...

# %% [markdown]
# ## Saving above to csv

# %%
df_news.to_csv('Webscaping News Articles.csv',index=False)
